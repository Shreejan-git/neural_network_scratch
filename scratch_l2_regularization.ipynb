# %% [markdown]
# ![Screenshot%20%2872%29.png](attachment:Screenshot%20%2872%29.png)

# %% [markdown]
#                                               Binary crossentropy

# %%
#Python code implementation of binary crossentropy.
# m = total number of data
# Y = Row vector of all actual value
# yhat = Row vector of all predicted value.
binary_crossentropy = np.multiply(-1/m,(np.dot(Y,log(yhat.T)) + np.dot((1-Y),(1-yhat.T))))

# %% [markdown]
# ![1_xn0T5GWAdViXHDw6zuhMSw.png](attachment:1_xn0T5GWAdViXHDw6zuhMSw.png)

# %% [markdown]
#                                          Derivation of binary crossentropy

# %%
#Code implementation of derivation of binary_crossentropy
d_cost = -1/m * (np.divide(Y,yhat) - np.divide((1-Y),(1-yhat)))

# %% [markdown]
# ![1_2wULsk4M4HG12bZ5cB-bPA.png](attachment:1_2wULsk4M4HG12bZ5cB-bPA.png)

# %% [markdown]
#                                                Weight Update formula

# %%
#Code implementation of weight updating formula
alpha = learning_rate
W_new = W_old - alpha * d_cost

# %% [markdown]
# ![binary_crossentropy_reg.png.crdownload.png](attachment:binary_crossentropy_reg.png.crdownload.png)

# %% [markdown]
#                                     Binary Crossentropy with L2 regularization

# %%
#Code implementation of binary crossentropy with L2 regularization
binary_crossentropy = np.multiply(-1/m,(np.dot(Y,log(yhat.T)) + np.dot((1-Y),(1-yhat.T)))) + np.sum(np.square(W))

# %% [markdown]
# ![20220628_105146.jpg](attachment:20220628_105146.jpg)

# %% [markdown]
#                                       derivation of L2 regularization

# %%
#derivation of cost function with respect to (w.r.t) W0 and L2 regularization
#internally, derivation will get computed w.r.t every weights
#lambda = regularization parameter.

d_cost = (-1/m * (np.divide(Y,yhat) - np.divide((1-Y),(1-yhat)))) + (lambda/m)*W0

# %% [markdown]
# ![20220628_110030.jpg](attachment:20220628_110030.jpg)

# %% [markdown]
#                    Updated weight-update formula after implementing derivative of L2 regularization

# %%
#Code implementation of updated weight-update formula
#alpha = learning_rate
#lambda = regularization parameter
W_new = (1 - (alpha*lambda)/m) * (W_old - alpha * d_cost)
